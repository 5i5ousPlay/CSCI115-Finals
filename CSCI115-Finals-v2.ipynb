# %%
# Standard libraries
import torch
from torch_geometric.utils import from_networkx
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from tqdm import tqdm
# NetworkX for graph handling
import networkx as nx
from sklearn.decomposition import PCA

# Torch and PyTorch Geometric for graph-based learning

# import torch.nn.functional as FZ
# from torch_geometric.nn import MessagePassing
# from torch_geometric.utils import from_networkx, add_self_loops, degree, remove_self_loops

# SciPy for handling matrix files
from scipy.io import mmread
import seaborn as sns

from generators import NetworkStructureGenerator, PopulationGenerator
from model import BeliefMessagePassing

# %%
G = nx.read_edgelist("datasets/facebook_combined.txt", create_using=nx.Graph())

# %%
pop_gen = PopulationGenerator(G)
x, alpha_matrix, confidence_bound = pop_gen.generate()

# %%
edge_index = from_networkx(G).edge_index

# %%
model = BeliefMessagePassing(in_channels=1, out_channels=1, num_timesteps=50)
final, over_time, edge_over_time, feature_snapshots, node_histories = model(x, edge_index, alpha_matrix, confidence_bound, verbose=True, N_max=10000, lambda_m=6, gamma=0.05)
# Out:
# Belief Propagation Steps:   0%|          | 0/50 [00:00<?, ?it/s]
# Timestep 0: Network Size: 4039 | Connections 176468
# Belief Propagation Steps:   2%|▏         | 1/50 [00:01<01:29,  1.82s/it]
# Timestep 1: Network Size: 4374 | Connections 100035
# Belief Propagation Steps:   4%|▍         | 2/50 [00:02<01:05,  1.37s/it]
# Timestep 2: Network Size: 4680 | Connections 101176
# Belief Propagation Steps:   6%|▌         | 3/50 [00:04<01:01,  1.32s/it]
# Timestep 3: Network Size: 4951 | Connections 118053
# Belief Propagation Steps:   8%|▊         | 4/50 [00:05<01:02,  1.36s/it]
# Timestep 4: Network Size: 5191 | Connections 135904
# Belief Propagation Steps:  10%|█         | 5/50 [00:09<01:42,  2.28s/it]
# Timestep 5: Network Size: 5492 | Connections 208588
# Belief Propagation Steps:  12%|█▏        | 6/50 [00:12<01:54,  2.60s/it]
# Timestep 6: Network Size: 5751 | Connections 263424
# Belief Propagation Steps:  14%|█▍        | 7/50 [00:13<01:33,  2.18s/it]
# Timestep 7: Network Size: 6000 | Connections 274334
# Belief Propagation Steps:  16%|█▌        | 8/50 [00:19<02:10,  3.11s/it]
# Timestep 8: Network Size: 6184 | Connections 363613
# Belief Propagation Steps:  18%|█▊        | 9/50 [00:22<02:11,  3.20s/it]
# Timestep 9: Network Size: 6396 | Connections 412190
# Belief Propagation Steps:  20%|██        | 10/50 [00:23<01:39,  2.50s/it]
# Timestep 10: Network Size: 6596 | Connections 402095
# Belief Propagation Steps:  22%|██▏       | 11/50 [00:25<01:35,  2.44s/it]
# Timestep 11: Network Size: 6718 | Connections 419488
# Belief Propagation Steps:  24%|██▍       | 12/50 [00:26<01:12,  1.91s/it]
# Timestep 12: Network Size: 6882 | Connections 401384
# Belief Propagation Steps:  26%|██▌       | 13/50 [00:28<01:09,  1.87s/it]
# Timestep 13: Network Size: 7021 | Connections 407674
# Belief Propagation Steps:  28%|██▊       | 14/50 [00:29<01:05,  1.82s/it]
# Timestep 14: Network Size: 7144 | Connections 414890
# Belief Propagation Steps:  30%|███       | 15/50 [00:35<01:45,  3.01s/it]
# Timestep 15: Network Size: 7230 | Connections 515604
# Belief Propagation Steps:  32%|███▏      | 16/50 [00:38<01:36,  2.83s/it]
# Timestep 16: Network Size: 7356 | Connections 529975
# Belief Propagation Steps:  34%|███▍      | 17/50 [00:39<01:15,  2.30s/it]
# Timestep 17: Network Size: 7411 | Connections 514642
# Belief Propagation Steps:  36%|███▌      | 18/50 [00:46<02:04,  3.89s/it]
# Timestep 18: Network Size: 7493 | Connections 652913
# Belief Propagation Steps:  38%|███▊      | 19/50 [00:51<02:09,  4.18s/it]
# Timestep 19: Network Size: 7529 | Connections 705956
# Belief Propagation Steps:  40%|████      | 20/50 [00:57<02:20,  4.70s/it]
# Timestep 20: Network Size: 7588 | Connections 796580
# Belief Propagation Steps:  42%|████▏     | 21/50 [01:01<02:07,  4.41s/it]
# Timestep 21: Network Size: 7651 | Connections 825653
# Belief Propagation Steps:  44%|████▍     | 22/50 [01:04<01:51,  3.97s/it]
# Timestep 22: Network Size: 7715 | Connections 834206
# Belief Propagation Steps:  46%|████▌     | 23/50 [01:08<01:50,  4.11s/it]
# Timestep 23: Network Size: 7733 | Connections 872508
# Belief Propagation Steps:  48%|████▊     | 24/50 [01:15<02:06,  4.85s/it]
# Timestep 24: Network Size: 7782 | Connections 968324
# Belief Propagation Steps:  50%|█████     | 25/50 [01:16<01:32,  3.69s/it]
# Timestep 25: Network Size: 7780 | Connections 903864
# Belief Propagation Steps:  52%|█████▏    | 26/50 [01:16<01:07,  2.83s/it]
# Timestep 26: Network Size: 7833 | Connections 849554
# Belief Propagation Steps:  54%|█████▍    | 27/50 [01:24<01:40,  4.37s/it]
# Timestep 27: Network Size: 7857 | Connections 970027
# Belief Propagation Steps:  56%|█████▌    | 28/50 [01:31<01:49,  4.99s/it]
# Timestep 28: Network Size: 7871 | Connections 1035754
# Belief Propagation Steps:  58%|█████▊    | 29/50 [01:36<01:45,  5.02s/it]
# Timestep 29: Network Size: 7891 | Connections 1081840

# %%
def plot_belief_over_time(beliefs_over_time, model, carrying_capacity, 
                          belief_threshold=0.5, disbelief_threshold=-0.5,
                          title="Belief Over Time",
                         show_pop=True):
    believers_over_time = []
    nonbelievers_over_time = []
    moderates_over_time = []
    if show_pop:
        pop_over_time = [x.shape[0] for x in beliefs_over_time]
    
    for timestep in beliefs_over_time:
        believers = (timestep > belief_threshold).sum(dim=0)
        believers_over_time.append(believers)
    
        nonbelievers = (timestep < disbelief_threshold).sum(dim=0)
        nonbelievers_over_time.append(nonbelievers)
    
        total_pop = timestep.shape[0]
        moderates = total_pop - (nonbelievers + believers)
        moderates_over_time.append(moderates if moderates > 0 else torch.tensor([0]))
    
    fig, ax = plt.subplots(figsize=(10,8))
    ax.plot(range(0,model.num_timesteps+1), believers_over_time, color='blue', label='Believers')
    ax.plot(range(0,model.num_timesteps+1), nonbelievers_over_time, color='red', label='Non-believers')
    ax.plot(range(0,model.num_timesteps+1), moderates_over_time, color='green', label='Unsure')
    if show_pop:
        ax.plot(range(0,model.num_timesteps+1), pop_over_time, linestyle='dashdot',
               color='gold', label="Population Size")
        ax.hlines(carrying_capacity, 0, model.num_timesteps+1, linestyle='dashed', color='orange',
                 label='Carrying Capacity')
    ax.legend(title='Groups', loc='center right')
    ax.set_title(title)
    ax.set_xlabel("Timestep")
    ax.set_ylabel("Count")
    ax.grid(True)

# %%
plot_belief_over_time(over_time, model, 10000)

# %%
average_belief = [x.mean() for x in over_time]
variance_ot = [torch.var(x) for x in over_time]
fig, ax = plt.subplots()
ax.plot(range(1, len(over_time) + 1), average_belief, color='green', label='Mean Belief')
ax.plot(range(1, len(over_time) + 1), variance_ot, color='red', linestyle='dotted', label="Belief Variance")
ax.set_title("Mean Belief & Belief Variance Over Time")
ax.set_xlabel("Timestep")
ax.legend(loc='center right')
ax.grid(True)

# %%
size = len(G.nodes)
PC = (size * (size-1))/2
density_ot = np.array([x.shape[1]/PC for x in edge_over_time])
density_growth = np.diff(density_ot)
window_size = 5
moving_avg_density_ot = np.convolve(density_ot, np.ones(window_size)/window_size, mode='valid')
fig, ax = plt.subplots()
ax.plot(range(0, len(over_time)), density_ot, label='Density')
ax.plot(range(1, len(density_growth) + 1), density_growth, label='Density Growth')
ax.plot(range(window_size - 1, len(density_ot)), moving_avg_density_ot, label="Moving Average", color='red', linestyle='dashed')
ax.set_title("Density over Time")
ax.set_xlabel("Timestep")
ax.set_ylabel("Density")
ax.legend()
ax.grid(True)

# %%
def get_communities_modularity_over_time(edgelist_over_time):
    communities_over_time = []
    modularity_over_time = []
    for edgelist in tqdm(edgelist_over_time, desc="Processing Edgelists"):
        el = list(map(tuple, edgelist.T.numpy()))
        G = nx.from_edgelist(el)
        communities = nx.community.louvain_communities(G, seed=42)
        communities_over_time.append(communities)
        modularity_over_time.append(nx.community.modularity(G, communities))
    return communities_over_time, modularity_over_time

# %%
communities_over_time, modularity_over_time = get_communities_modularity_over_time(edge_over_time)

# %%
fig, ax = plt.subplots(nrows=2,figsize=(10,12))
community_count = [len(communities) for communities in communities_over_time]
window_size = 5
moving_avg_community_count = np.convolve(community_count, np.ones(window_size)/window_size, mode='valid')
ax[0].plot(range(0, len(over_time)), community_count, label='Community Count')
ax[0].plot(range(window_size - 1, len(community_count)), moving_avg_community_count, 
        label='Community Count (Moving Avg.)', color='red', linestyle='dashed')
ax[0].set_title("Community Count Over Time")
ax[0].set_xlabel("Timestep")
ax[0].set_ylabel("Community Count")
ax[0].legend()
ax[0].grid(True)

avg_community_size = []
for communities in communities_over_time:
    community_sizes = np.array([len(community) for community in communities])
    avg_community_size.append(community_sizes.mean())
moving_avg_community_size = np.convolve(avg_community_size, np.ones(window_size)/window_size,
                                        mode='valid')
ax[1].plot(range(0, len(over_time)), avg_community_size, label='Community Size')
ax[1].plot(range(window_size - 1, len(avg_community_size)), moving_avg_community_size,
          label='Community Size (Moving Avg.)', color='red', linestyle='dashed')
ax[1].set_title("Average Community Size")
ax[1].set_xlabel("Timestep")
ax[1].set_ylabel("Avg. Community Size")
ax[1].grid(True)
ax[1].legend()

# %%
fig, ax = plt.subplots()
ax.plot(range(0, len(modularity_over_time)), modularity_over_time)
ax.set_label("Timestep")
ax.set_ylabel("Modularity")
ax.set_title("Modularity Over Time")
ax.grid(True)

# %%
len(node_histories)
# Out:
# 24503

# %%
def node_history_to_df(node_histories):
    data = []
    for node in node_histories:
        history = np.array(node_histories[node])
        # if history.ndim < 2 or history.shape[0] == 0:
        #     continue
            
        openness = history[0,1]
        c_bound = history[0,2]
        
        # belief
        belief = history[:, 0]
        avg_belief = belief.mean()
        std_belief = belief.std()
        start_belief = belief[0]
        last_belief = belief[-1]
        range_belief = np.ptp(belief)
        belief_mean_step_grad = np.diff(belief).mean() if len(belief) > 1 else 0.0
        
        # degree
        deg = history[:, 3]
        avg_deg = deg.mean()
        std_deg = deg.std()
        start_deg = deg[0]
        last_deg = deg[-1]
        range_deg = np.ptp(deg)
        deg_mean_step_grad = np.diff(deg).mean() if len(deg) > 1 else 0.0
    
        # lifetime
        lifetime = history.shape[0]

        row = np.array([avg_belief, std_belief, start_belief, last_belief, range_belief, belief_mean_step_grad,
               avg_deg, std_deg, start_deg, last_deg, range_deg, deg_mean_step_grad, 
               openness, c_bound, lifetime])
        data.append(row)
        # print(data)

    columns = ['avg_belief', 'std_belief', 'start_belief', 'last_belief', 'range_belief', 'belief_mean_step_grad',
              'avg_deg', 'std_deg', 'start_deg', 'last_deg', 'range_deg', 'deg_mean_step_grad', 'openness', 'c_bound', 'lifetime']
    df = pd.DataFrame(data, columns=columns)
    return df

# %%
df = node_history_to_df(node_histories)

# %%
df
# Out:
#        avg_belief  std_belief  start_belief  last_belief  range_belief  \
# 0        0.414456    0.053341      0.051588     0.424514      0.372927
# 1        0.427150    0.022640      0.456465     0.400326      0.056139
# 2        0.275013    0.259031     -0.537471     0.399797      0.937269
# 3        0.417855    0.031089      0.566749     0.408075      0.158693
# 4        0.308860    0.231174     -0.513567     0.399865      0.913436
# ...           ...         ...           ...          ...           ...
# 24498    0.424296    0.000000      0.424296     0.424296      0.000000
# 24499    0.827491    0.000000      0.827491     0.827491      0.000000
# 24500    0.508624    0.000000      0.508624     0.508624      0.000000
# 24501    0.775233    0.000000      0.775233     0.775233      0.000000
# 24502    0.005472    0.000000      0.005472     0.005472      0.000000
#
#        belief_mean_step_grad     avg_deg     std_deg  start_deg  last_deg  \
# 0                   0.007459  433.901961  184.285824      347.0     609.0
# 1                  -0.011228   11.833333    2.409472       17.0      10.0
# 2                   0.033474    0.724138    1.817474       10.0       1.0
# 3                  -0.005472  269.400000  196.650553       17.0     408.0
# 4                   0.026866  110.228571  107.375732       10.0     185.0
# ...                      ...         ...         ...        ...       ...
# 24498               0.000000    6.000000    0.000000        6.0       6.0
# 24499               0.000000    6.000000    0.000000        6.0       6.0
# 24500               0.000000    7.000000    0.000000        7.0       7.0
# 24501               0.000000    4.000000    0.000000        4.0       4.0
# 24502               0.000000    4.000000    0.000000        4.0       4.0
#
#        range_deg  deg_mean_step_grad  openness   c_bound  lifetime
# 0          621.0            5.240000  0.681873  0.209085      51.0
# 1            7.0           -1.400000  0.304575  0.488385       6.0
# 2           10.0           -0.321429  0.354499  0.193013      29.0
# 3          600.0           13.482759  0.431372  0.354446      30.0
# 4          278.0            5.147059  0.354322  0.163096      35.0
# ...          ...                 ...       ...       ...       ...
# 24498        0.0            0.000000  0.916174  0.019947       1.0
# 24499        0.0            0.000000  0.246034  0.332277       1.0
# 24500        0.0            0.000000  0.325971  0.087747       1.0
# 24501        0.0            0.000000  0.567126  0.220299       1.0
# 24502        0.0            0.000000  0.802396  0.201780       1.0
#
# [24503 rows x 15 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from collections import Counter
from sklearn.preprocessing import StandardScaler

# %%
min_samples = range(10,21)
eps = np.arange(0.05,0.13, 0.01)

sc = StandardScaler()
stdDf = pd.DataFrame(sc.fit_transform(df), columns=df.columns)
# Out:
# Testing Min Samples: 100%|█████████████████████████████████████████████████████████████| 10/10 [08:20<00:00, 50.01s/it]

# %%
corr = df.select_dtypes('number').corr()
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
temp = corr['lifetime'].sort_values().drop("lifetime").reset_index()
ax.barh(temp['index'], temp['lifetime'])
ax.set_title("Lifetime Correlations")
ax.set_xlabel("Correlation")
# Out:
# Text(0.5, 0, 'Correlation')

# %%
inertia = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(stdDf)
    inertia.append(kmeans.inertia_)

fig, ax = plt.subplots()
ax.plot(range(2,11), inertia, marker='o')
ax.set_title("Inertia")
# Out:
# Text(0.5, 1.0, 'Inertia')

# %%
silhouette_scores = []
for i in tqdm(range(2, 11), desc='Testing KMeans Silhoette Score'):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(stdDf)
    ss = silhouette_score(stdDf, kmeans.labels_)
    silhouette_scores.append(ss)
# Out:
# Testing KMeans Silhoette Score: 100%|████████████████████████████████████████████████████| 9/9 [00:48<00:00,  5.42s/it]

# %%
fig, ax = plt.subplots()
ax.plot(range(2,11), silhouette_scores, marker='o')
ax.set_title("Silhouette Scores")
# Out:
# Text(0.5, 1.0, 'Silhouette Scores')

# %%
kmeans = KMeans(n_clusters=5)
df['kmeans_label'] = kmeans.fit_predict(stdDf)

# %%
df.groupby('kmeans_label').mean()
# Out:
#               avg_belief  std_belief  start_belief  last_belief  range_belief  \
# kmeans_label
# 0               0.369671    0.135293      0.006693     0.410370      0.566577
# 1               0.417000    0.076884      0.437902     0.412497      0.236070
# 2               0.375689    0.102933      0.174134     0.400961      0.425781
# 3              -0.324687    0.076986     -0.442600    -0.233639      0.208963
# 4               0.136548    0.315464     -0.592492     0.367053      0.959548
#
#               belief_mean_step_grad     avg_deg     std_deg  start_deg  \
# kmeans_label
# 0                          0.020917  275.258600  215.804564  12.484569
# 1                         -0.011616   16.502697    9.737722  10.597575
# 2                          0.008801  123.045858   95.592425  18.592406
# 3                          0.061510   11.131460    7.014363  11.207755
# 4                          0.161020   24.220087   21.038389   9.905267
#
#                 last_deg   range_deg  deg_mean_step_grad  openness   c_bound  \
# kmeans_label
# 0             500.687241  642.611700           27.820363  0.582436  0.300128
# 1              23.121603   27.455199            0.987608  0.479396  0.247547
# 2             213.493602  286.616530           11.634643  0.525344  0.271860
# 3              13.313056   19.528282           -1.482929  0.290733  0.254098
# 4              42.800103   59.212209            2.875690  0.569185  0.249014
#
#                lifetime  optics_label
# kmeans_label
# 0             28.191617     -1.000000
# 1             10.129351     -1.000000
# 2             26.914621     -1.000000
# 3              5.270011     -1.000000
# 4             12.531464     -0.992818

# %%
cluster_df = df.copy()
cluster_df
# Out:
#        avg_belief  std_belief  start_belief  last_belief  range_belief  \
# 0        0.414456    0.053341      0.051588     0.424514      0.372927
# 1        0.427150    0.022640      0.456465     0.400326      0.056139
# 2        0.275013    0.259031     -0.537471     0.399797      0.937269
# 3        0.417855    0.031089      0.566749     0.408075      0.158693
# 4        0.308860    0.231174     -0.513567     0.399865      0.913436
# ...           ...         ...           ...          ...           ...
# 24498    0.424296    0.000000      0.424296     0.424296      0.000000
# 24499    0.827491    0.000000      0.827491     0.827491      0.000000
# 24500    0.508624    0.000000      0.508624     0.508624      0.000000
# 24501    0.775233    0.000000      0.775233     0.775233      0.000000
# 24502    0.005472    0.000000      0.005472     0.005472      0.000000
#
#        belief_mean_step_grad     avg_deg     std_deg  start_deg  last_deg  \
# 0                   0.007459  433.901961  184.285824      347.0     609.0
# 1                  -0.011228   11.833333    2.409472       17.0      10.0
# 2                   0.033474    0.724138    1.817474       10.0       1.0
# 3                  -0.005472  269.400000  196.650553       17.0     408.0
# 4                   0.026866  110.228571  107.375732       10.0     185.0
# ...                      ...         ...         ...        ...       ...
# 24498               0.000000    6.000000    0.000000        6.0       6.0
# 24499               0.000000    6.000000    0.000000        6.0       6.0
# 24500               0.000000    7.000000    0.000000        7.0       7.0
# 24501               0.000000    4.000000    0.000000        4.0       4.0
# 24502               0.000000    4.000000    0.000000        4.0       4.0
#
#        range_deg  deg_mean_step_grad  openness   c_bound  lifetime  \
# 0          621.0            5.240000  0.681873  0.209085      51.0
# 1            7.0           -1.400000  0.304575  0.488385       6.0
# 2           10.0           -0.321429  0.354499  0.193013      29.0
# 3          600.0           13.482759  0.431372  0.354446      30.0
# 4          278.0            5.147059  0.354322  0.163096      35.0
# ...          ...                 ...       ...       ...       ...
# 24498        0.0            0.000000  0.916174  0.019947       1.0
# 24499        0.0            0.000000  0.246034  0.332277       1.0
# 24500        0.0            0.000000  0.325971  0.087747       1.0
# 24501        0.0            0.000000  0.567126  0.220299       1.0
# 24502        0.0            0.000000  0.802396  0.201780       1.0
#
#        optics_label  kmeans_label
# 0                -1             0
# 1                -1             1
# 2                -1             4
# 3                -1             0
# 4                -1             2
# ...             ...           ...
# 24498            -1             1
# 24499            -1             1
# 24500            -1             1
# 24501            -1             1
# 24502            -1             3
#
# [24503 rows x 17 columns]

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(stdDf)
cluster_df['PCA1'] = x_pca[:,0]
cluster_df['PCA2'] = x_pca[:,1]
cluster_df
# Out:
#        avg_belief  std_belief  start_belief  last_belief  range_belief  \
# 0        0.414456    0.053341      0.051588     0.424514      0.372927
# 1        0.427150    0.022640      0.456465     0.400326      0.056139
# 2        0.275013    0.259031     -0.537471     0.399797      0.937269
# 3        0.417855    0.031089      0.566749     0.408075      0.158693
# 4        0.308860    0.231174     -0.513567     0.399865      0.913436
# ...           ...         ...           ...          ...           ...
# 24498    0.424296    0.000000      0.424296     0.424296      0.000000
# 24499    0.827491    0.000000      0.827491     0.827491      0.000000
# 24500    0.508624    0.000000      0.508624     0.508624      0.000000
# 24501    0.775233    0.000000      0.775233     0.775233      0.000000
# 24502    0.005472    0.000000      0.005472     0.005472      0.000000
#
#        belief_mean_step_grad     avg_deg     std_deg  start_deg  last_deg  \
# 0                   0.007459  433.901961  184.285824      347.0     609.0
# 1                  -0.011228   11.833333    2.409472       17.0      10.0
# 2                   0.033474    0.724138    1.817474       10.0       1.0
# 3                  -0.005472  269.400000  196.650553       17.0     408.0
# 4                   0.026866  110.228571  107.375732       10.0     185.0
# ...                      ...         ...         ...        ...       ...
# 24498               0.000000    6.000000    0.000000        6.0       6.0
# 24499               0.000000    6.000000    0.000000        6.0       6.0
# 24500               0.000000    7.000000    0.000000        7.0       7.0
# 24501               0.000000    4.000000    0.000000        4.0       4.0
# 24502               0.000000    4.000000    0.000000        4.0       4.0
#
#        range_deg  deg_mean_step_grad  openness   c_bound  lifetime  \
# 0          621.0            5.240000  0.681873  0.209085      51.0
# 1            7.0           -1.400000  0.304575  0.488385       6.0
# 2           10.0           -0.321429  0.354499  0.193013      29.0
# 3          600.0           13.482759  0.431372  0.354446      30.0
# 4          278.0            5.147059  0.354322  0.163096      35.0
# ...          ...                 ...       ...       ...       ...
# 24498        0.0            0.000000  0.916174  0.019947       1.0
# 24499        0.0            0.000000  0.246034  0.332277       1.0
# 24500        0.0            0.000000  0.325971  0.087747       1.0
# 24501        0.0            0.000000  0.567126  0.220299       1.0
# 24502        0.0            0.000000  0.802396  0.201780       1.0
#
#        optics_label  kmeans_label      PCA1      PCA2
# 0                -1             0  6.536191  0.436306
# 1                -1             1 -0.889119 -2.097690
# 2                -1             4 -1.003957  1.091006
# 3                -1             0  4.515097 -0.670002
# 4                -1             2  1.440173  1.475149
# ...             ...           ...       ...       ...
# 24498            -1             1 -1.079765 -2.123920
# 24499            -1             1 -0.415648 -3.187272
# 24500            -1             1 -1.057083 -2.461951
# 24501            -1             1 -0.483317 -3.000349
# 24502            -1             3 -1.803208 -1.166769
#
# [24503 rows x 19 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(x=cluster_df['PCA1'], y=cluster_df['PCA2'], hue=cluster_df['kmeans_label'], ax=ax)
ax.set_title("Node Feature Clustering (PCA)")
# Out:
# Text(0.5, 1.0, 'Node Feature Clustering (PCA)')

# %%
cluster_attr = df.groupby("kmeans_label").mean().round(2).drop("optics_label", axis=1)
cluster_attr.T.to_csv("Node Feature Clusters Attributes.csv")

# %%
cluster_attr.T
# Out:
# kmeans_label                0      1       2      3      4
# avg_belief               0.37   0.42    0.38  -0.32   0.14
# std_belief               0.14   0.08    0.10   0.08   0.32
# start_belief             0.01   0.44    0.17  -0.44  -0.59
# last_belief              0.41   0.41    0.40  -0.23   0.37
# range_belief             0.57   0.24    0.43   0.21   0.96
# belief_mean_step_grad    0.02  -0.01    0.01   0.06   0.16
# avg_deg                275.26  16.50  123.05  11.13  24.22
# std_deg                215.80   9.74   95.59   7.01  21.04
# start_deg               12.48  10.60   18.59  11.21   9.91
# last_deg               500.69  23.12  213.49  13.31  42.80
# range_deg              642.61  27.46  286.62  19.53  59.21
# deg_mean_step_grad      27.82   0.99   11.63  -1.48   2.88
# openness                 0.58   0.48    0.53   0.29   0.57
# c_bound                  0.30   0.25    0.27   0.25   0.25
# lifetime                28.19  10.13   26.91   5.27  12.53
